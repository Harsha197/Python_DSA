# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsha197/Python_DSA/blob/main/Day_4_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x="python is a programming language"
vowels="AEIOUaeiou"
vowel_count=0
for char in x:
  if char in vowels:
    vowel_count+=1
print(f"the count of vowels in the word is:",vowel_count)
# Out:
# the count of vowels in the word is: 10

# %%
user=input("Enter a string:")
result=""
for char in user:
  if char not in result:
    result+=char
print("String After Removing duplicates:",result)
# Out:
# Enter a string:harshaaha
# String After Removing duplicates: hars

# %%
def reverse_string(s):
    result = ""
    for char in s:
        result = char + result
    return result
print(reverse_string("harsha"))
# Out:
# ahsrah

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")
str1 = str1.replace(" ", "").lower()
str2 = str2.replace(" ", "").lower()
if sorted(str1) == sorted(str2):
    print("Anagram")
else:
    print("Not an Anagram")
# Out:
# Enter first string: Hello
# Enter second string: Harsha
# Not an Anagram
